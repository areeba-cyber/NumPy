# %% [markdown]
# Categorical Data Plots (Qualitative Type)
# boxplot
# violinplot
# stripplot
# swarmplot
# barplot
# countplot

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Aggression [(Aggregate Functions = Reduces a set of values into single summary value), used to summarize and analyze data, used with groupby() function]

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
# Whole dataFrame
print(df.mean(numeric_only=True))
print(df.sum(numeric_only=True))
print(df.min(numeric_only=True))
print(df.max(numeric_only=True))
print(df.count())

# Single Column
print(df["age"].mean())
print(df["age"].min())
print(df["age"].max())
print(df["age"].sum())
print(df["age"].count())
# Out:
# id        6.500000
# age      22.416667
# score    84.416667
# dtype: float64
# id         78
# age       269
# score    1013
# dtype: int64
# id        1
# age      20
# score    68
# dtype: int64
# id       12
# age      26
# score    97
# dtype: int64
# id        12
# name      12
# age       12
# city      12
# course    12
# score     12
# dtype: int64
# 22.416666666666668
# 20
# 26
# 269
# 12

# %% [markdown]
# Data Cleaning (The process of fixing or removing irrelevant or wrong data / 75% work done with pandas is data cleaning)

# %%
df = pd.read_csv("data.csv")
# drop irrelevant column
df = df.drop(columns=["age","score"])
print(df)

# Handle missing data
# df2 = df.dropna(subset=["age"])
# df2 = df.fillna({"age":67})
# print(df2)

# Fix inconsistent values
df["course"] = df["course"].replace({"Python":"PYTHON"})
print(df)

# Standarize text
df["name"] = df["name"].str.lower()
print(df.to_string())

# Fixing dataTypes
# df["age"] = df["age"].astype(bool)
# print(df)

# Removing Duplicates
# df = df.drop_duplicates()
# Out:
#     id    name        city  course
# 0    1     Ali      Lahore  Python
# 1    2  Ayesha   Islamabad  Pandas
# 2    3   Hamza     Karachi   NumPy
# 3    4    Sara       Okara  Python
# 4    5   Usman      Multan  Pandas
# 5    6    Hina  Faisalabad   NumPy
# 6    7   Bilal      Lahore  Python
# 7    8   Maham  Rawalpindi  Pandas
# 8    9    Zain       Okara  Python
# 9   10    Iqra   Islamabad   NumPy
# 10  11   Ahmed     Karachi  Pandas
# 11  12  Fatima      Multan  Python
#     id    name        city  course
# 0    1     Ali      Lahore  PYTHON
# 1    2  Ayesha   Islamabad  Pandas
# 2    3   Hamza     Karachi   NumPy
# 3    4    Sara       Okara  PYTHON
# 4    5   Usman      Multan  Pandas
# 5    6    Hina  Faisalabad   NumPy
# 6    7   Bilal      Lahore  PYTHON
# 7    8   Maham  Rawalpindi  Pandas
# 8    9    Zain       Okara  PYTHON
# 9   10    Iqra   Islamabad   NumPy
# 10  11   Ahmed     Karachi  Pandas
# 11  12  Fatima      Multan  PYTHON
#     id    name        city  course
# 0    1     ali      Lahore  PYTHON
# 1    2  ayesha   Islamabad  Pandas
# 2    3   hamza     Karachi   NumPy
# 3    4    sara       Okara  PYTHON
# 4    5   usman      Multan  Pandas
# 5    6    hina  Faisalabad   NumPy
# 6    7   bilal      Lahore  PYTHON
# 7    8   maham  Rawalpindi  Pandas
# 8    9    zain       Okara  PYTHON
# 9   10    iqra   Islamabad   NumPy
# 10  11   ahmed     Karachi  Pandas
# 11  12  fatima      Multan  PYTHON
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\NumPy_Pandas\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 20
#      16 df["name"] = df["name"].str.lower()
#      17 print(df.to_string())
#      18
#      19 # Fixing dataTypes
# ---> 20 df["age"] = df["age"].astype(bool)
#      21 print(df)
#
# File ~\Desktop\NumPy_Pandas\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\Desktop\NumPy_Pandas\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'age'
